# %%
import pandas as pd
import matplotlib.pyplot as plt

# Step 1: Load CSV
df = pd.read_csv('/1_The_Schedule_of_GE_to_Lok_Sabha_ii_0 (1).csv')  # Replace 'data.csv' with your file name

# Step 2: Plot Bar Chart
plt.bar(df['States and Union Territories'], df['No. Of Phases'])

# Step 3: Customize the chart
plt.title('Bar Chart Example')
plt.xlabel('No. Of Phases')
plt.ylabel('States and Union Territories')

# Step 4: Show the plot
plt.show()
